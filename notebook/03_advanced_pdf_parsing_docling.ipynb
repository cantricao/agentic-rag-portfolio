# %%
# !pip install -q docling "huggingface_hub[cli]"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# WARNING: huggingface-hub 1.3.7 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.4.1 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.4.0 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.3.5 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.3.4 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.3.3 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.3.2 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.3.1 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.3.0 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.2.4 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.2.3 does not provide the extra 'cli'
# WARNING: huggingface-hub 1.2.2 does not provide the extra 'cli'
# ...

# %%
import time
from docling.document_converter import DocumentConverter

# Advanced PDF Parsing: Extracts structure, tables, and text
# Unlike PyPDF, Docling preserves layout awareness.

converter = DocumentConverter()

# %%
# This can be a local file path or a URL
source = "https://assets.accessible-digital-documents.com/uploads/2017/01/sample-tables.pdf"  # The Docling technical paper itself
# source = "https://www.w3.org/WAI/WCAG20/Techniques/working-examples/PDF20/table.pdf"
start_time = time.time()
result = converter.convert(source)

end_time = time.time()

# Export to markdown - clean, structured, beautiful
print(result.document.export_to_markdown())

print(f"⏱️ Running time: {end_time - start_time:.2f} second")
# Out:
# ## Design and build accessible PDF tables Sample tables
#
# Table 1
#
# | Column header (TH)   | Column header (TH)   | Column header (TH)   |
# |----------------------|----------------------|----------------------|
# | Data cell (TD)       | Data cell (TD)       | Row header (TH)      |
# | Data cell (TD)       | Data cell (TD)       | Row header(TH)       |
#
# Table 2: example of footnotes referenced from within a table
#
# | Expenditure by function £ million   | Expenditure by function £ million   |   2009/10 |   2010/11 1 |
# |-------------------------------------|-------------------------------------|-----------|-------------|
# | Policy functions                    | Financial                           |     22.5  |       30.57 |
# | Policy functions                    | Information 2                       |     10.2  |       14.8  |
# | Policy functions                    | Contingency                         |      2.6  |        1.2  |
# ...
